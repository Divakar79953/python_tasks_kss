# %% [markdown]
# ![](https://housing.com/news/wp-content/uploads/2022/11/iris-flower-compressed.jpg)
# <div style="padding: 10px;color:white;margin:10;font-size:200%;text-align:center;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://www.yates.com.au/media/plants/flowers-and-ornamentals/flowers/flowers-iris-image1.jpg?mode=crop&anchor=center&widthratio=1.5&height=576&format=jpg)"><b><span style='color:Yellow;font-size:60px; font-family:Times New Roman;'> IRIS FLOWER CLASSIFICATION </span></b> </div>
# <h3 style="background-image: url(https://img.freepik.com/premium-photo/purple-iris-flowers-purple-background-copy-space_58797-2607.jpg);font-family:Times New Roman; font-size:25px; ">Iris flower classification is a classic machine learning problem in which the goal is to classify iris flowers into one of three species: Setosa, Versicolor, and Virginica, based on certain features such as sepal length, sepal width, petal length, and petal width.
# The dataset used for this task is commonly known as the Iris dataset, and it was introduced by British biologist and statistician Ronald A. Fisher in 1936. The dataset contains 150 samples of iris flowers, with 50 samples for each of the three species. Each sample has four features (sepal length, sepal width, petal length, and petal width), and the species label as the target variable.</h3>
#
#
#
# ![](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Machine+Learning+R/iris-machinelearning.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /kaggle/input/iriscsv/Iris.csv

# %% [markdown]
# <div style="padding: 0px;color:white;margin:10;font-size:200%;text-align:center;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://housing.com/news/wp-content/uploads/2022/11/iris-flower-compressed.jpg)"><b><span style='color:Yellow;font-size:60px;'> Getting Started </span></b> </div>

# %%
df = pd.read_csv('/kaggle/input/iriscsv/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# <div style="padding: 0px;color:white;margin:10;font-size:200%;text-align:center;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://housing.com/news/wp-content/uploads/2022/11/iris-flower-compressed.jpg)"><b><span style='color:Yellow;font-size:60px;'> Exploratory Data Analysis</span></b> </div>

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.rename(columns={'SepalLengthCm':'Sepal Length Cm','SepalWidthCm':'Sepal Width Cm','PetalLengthCm':'Petal Length Cm','PetalWidthCm':'Petal Width Cm',},inplace=True)

# %%
df.head(10)
# Out:
#    Id  Sepal Length Cm  Sepal Width Cm  Petal Length Cm  Petal Width Cm  \
# 0   1              5.1             3.5              1.4             0.2
# 1   2              4.9             3.0              1.4             0.2
# 2   3              4.7             3.2              1.3             0.2
# 3   4              4.6             3.1              1.5             0.2
# 4   5              5.0             3.6              1.4             0.2
# 5   6              5.4             3.9              1.7             0.4
# 6   7              4.6             3.4              1.4             0.3
# 7   8              5.0             3.4              1.5             0.2
# 8   9              4.4             2.9              1.4             0.2
# 9  10              4.9             3.1              1.5             0.1
#
#        Species
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa
# 5  Iris-setosa
# 6  Iris-setosa
# 7  Iris-setosa
# 8  Iris-setosa
# ...

# %%
spec =  df['Species'].unique()
for species in spec:
    print("->",species)
# Out:
# -> Iris-setosa
# -> Iris-versicolor
# -> Iris-virginica

# %% [markdown]
# <div style="padding: 0px;color:white;margin:10;font-size:200%;text-align:center;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://housing.com/news/wp-content/uploads/2022/11/iris-flower-compressed.jpg)"><b><span style='color:Yellow;font-size:60px;'> Iris-setosa</span></b> </div>
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/a/a7/Irissetosa1.jpg">

# %%
Iris_setosa = df[df['Species'] == 'Iris-setosa'].value_counts().sum()
print( "Number of Iris-setosa:- ",Iris_setosa)
df[df['Species'] == 'Iris-setosa' ]
# Out:
# Number of Iris-setosa:-  50
#     Id  Sepal Length Cm  Sepal Width Cm  Petal Length Cm  Petal Width Cm  \
# 0    1              5.1             3.5              1.4             0.2
# 1    2              4.9             3.0              1.4             0.2
# 2    3              4.7             3.2              1.3             0.2
# 3    4              4.6             3.1              1.5             0.2
# 4    5              5.0             3.6              1.4             0.2
# 5    6              5.4             3.9              1.7             0.4
# 6    7              4.6             3.4              1.4             0.3
# 7    8              5.0             3.4              1.5             0.2
# 8    9              4.4             2.9              1.4             0.2
# 9   10              4.9             3.1              1.5             0.1
# 10  11              5.4             3.7              1.5             0.2
# ...

# %% [markdown]
# <div style="padding: 0px;color:white;margin:10;font-size:200%;text-align:center;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://housing.com/news/wp-content/uploads/2022/11/iris-flower-compressed.jpg)"><b><span style='color:Yellow;font-size:60px;'> Iris-versicolor</span></b> </div>
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/41/Iris_versicolor_3.jpg/1280px-Iris_versicolor_3.jpg">

# %%
Iris_versicolor = df[df['Species'] == 'Iris-versicolor'].value_counts().sum()
print( "Number of Iris-versicolor:- ",Iris_versicolor)
df[df['Species'] == 'Iris-versicolor' ]
# Out:
# Number of Iris-versicolor:-  50
#      Id  Sepal Length Cm  Sepal Width Cm  Petal Length Cm  Petal Width Cm  \
# 50   51              7.0             3.2              4.7             1.4
# 51   52              6.4             3.2              4.5             1.5
# 52   53              6.9             3.1              4.9             1.5
# 53   54              5.5             2.3              4.0             1.3
# 54   55              6.5             2.8              4.6             1.5
# 55   56              5.7             2.8              4.5             1.3
# 56   57              6.3             3.3              4.7             1.6
# 57   58              4.9             2.4              3.3             1.0
# 58   59              6.6             2.9              4.6             1.3
# 59   60              5.2             2.7              3.9             1.4
# 60   61              5.0             2.0              3.5             1.0
# ...

# %% [markdown]
# <div style="padding: 0px;color:white;margin:10;font-size:200%;text-align:center;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://housing.com/news/wp-content/uploads/2022/11/iris-flower-compressed.jpg)"><b><span style='color:Yellow;font-size:60px;'> Iris-virginica</span></b> </div>
#
# <img src="https://mellowmarshfarm.com/wp-content/uploads/2022/02/DETA-7163_Iris-virginica.jpg">

# %%
Iris_virginica = df[df['Species'] == 'Iris-virginica'].value_counts().sum()
print( "Number of Iris-virginica:- ",Iris_virginica)
df[df['Species'] == 'Iris-virginica' ]
# Out:
# Number of Iris-virginica:-  50
#       Id  Sepal Length Cm  Sepal Width Cm  Petal Length Cm  Petal Width Cm  \
# 100  101              6.3             3.3              6.0             2.5
# 101  102              5.8             2.7              5.1             1.9
# 102  103              7.1             3.0              5.9             2.1
# 103  104              6.3             2.9              5.6             1.8
# 104  105              6.5             3.0              5.8             2.2
# 105  106              7.6             3.0              6.6             2.1
# 106  107              4.9             2.5              4.5             1.7
# 107  108              7.3             2.9              6.3             1.8
# 108  109              6.7             2.5              5.8             1.8
# 109  110              7.2             3.6              6.1             2.5
# 110  111              6.5             3.2              5.1             2.0
# ...

# %%
column = df.columns
for columns in column:
    print("->",columns)
# Out:
# -> Id
# -> Sepal Length Cm
# -> Sepal Width Cm
# -> Petal Length Cm
# -> Petal Width Cm
# -> Species

# %%
# Data visualization
# Pairplot
sns.pairplot(df, hue='Species', diag_kind='hist')
plt.show()

# Box plot
sns.boxplot(x='Species', y='Sepal Length Cm', data=df)
plt.title('Sepal Length by Species')
plt.show()

# Violin plot
sns.violinplot(x='Species', y='Petal Length Cm', data=df)
plt.title('Petal Length by Species')
plt.show()

# Swarm plot
sns.swarmplot(x='Species', y='Petal Width Cm', data=df)
plt.title('Petal Width by Species')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:3544: UserWarning: 6.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:3544: UserWarning: 18.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(16,7))
x = plt.xticks(rotation=90)
sns.kdeplot(data=df,x="Sepal Length Cm", hue='Species', shade=True)
# Out:
# /tmp/ipykernel_36/3667328554.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df,x="Sepal Length Cm", hue='Species', shade=True)
# <Axes: xlabel='Sepal Length Cm', ylabel='Density'>

# %%
# plt.figure(figsize=(16,7))
x = plt.xticks(rotation=90)
sns.barplot(x=df['Species'],y=df['Sepal Width Cm'])
# Out:
# <Axes: xlabel='Species', ylabel='Sepal Width Cm'>
